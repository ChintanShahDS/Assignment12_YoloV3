# %%
# !git clone https://github.com/shylane/YoloV3.git
# Out:
# fatal: destination path 'YoloV3' already exists and is not an empty directory.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd YoloV3
# !mkdir weights
# Out:
# /content/YoloV3
# mkdir: cannot create directory ‘weights’: File exists

# %%
# !cp /content/drive/MyDrive/yolov3-spp-ultralytics.pt weights

# %%
# !cp -r /content/drive/MyDrive/Workspace/numberplate data/

# %%
# !python train.py --data data/numberplate/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 100
# Out:
# Namespace(epochs=100, batch_size=10, accumulate=4, cfg='cfg/yolov3-custom.cfg', data='data/numberplate/custom.data', multi_scale=False, img_size=[512], rect=False, resume=False, nosave=False, notest=False, evolve=False, bucket='', cache_images=True, weights='weights/yolov3-spp-ultralytics.pt', name='', device='', adam=False, single_cls=False)
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15102MB)
#
# 2024-04-28 13:30:25.243837: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-28 13:30:25.243902: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
# !python detect.py --weights /content/YoloV3/weights/best.pt --source /content/YoloV3/data/numberplate/testimages
# Out:
# Namespace(cfg='cfg/yolov3-custom.cfg', names='data/customdata/custom.names', weights='/content/YoloV3/weights/best.pt', source='/content/YoloV3/data/numberplate/testimages', output='output', img_size=512, conf_thres=0.3, iou_thres=0.6, fourcc='mp4v', half=False, device='', view_img=False, save_txt=False, classes=None, agnostic_nms=False, augment=False)
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15102MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/30 /content/YoloV3/data/numberplate/testimages/numberplateTest1.jpg: 384x512 Done. (0.043s)
# ...

# %%
# !cp -r /content/YoloV3/output /content/drive/MyDrive/Workspace/numberplate/testoutput

# %%
# !rm -r /content/YoloV3/data/numberplate/testimages

# %%
# !cp /content/YoloV3/weights/best.pt /content/drive/MyDrive/Workspace/numberplate/testoutput
